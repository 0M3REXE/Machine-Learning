# %% [markdown]
# <a href="https://colab.research.google.com/github/0M3REXE/Machine-Learning/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://archive.ics.uci.edu/static/public/994/micro+gas+turbine+electrical+energy+prediction.zip
# Out:
# --2025-03-26 17:05:44--  https://archive.ics.uci.edu/static/public/994/micro+gas+turbine+electrical+energy+prediction.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘micro+gas+turbine+electrical+energy+prediction.zip’
#
# micro+gas+turbine+e     [    <=>             ] 887.52K  1015KB/s    in 0.9s
#
# 2025-03-26 17:05:45 (1015 KB/s) - ‘micro+gas+turbine+electrical+energy+prediction.zip’ saved [908821]

# %%
# !unzip micro+gas+turbine+electrical+energy+prediction.zip
# Out:
# Archive:  micro+gas+turbine+electrical+energy+prediction.zip
#   inflating: test.zip
#   inflating: train.zip

# %%
# !unzip test.zip
# Out:
# Archive:  test.zip
#    creating: test/
#   inflating: test/ex_22.csv
#   inflating: test/ex_4.csv

# %%
# !unzip train.zip
# Out:
# Archive:  train.zip
#    creating: train/
#   inflating: train/ex_24.csv
#   inflating: train/ex_1.csv
#   inflating: train/ex_21.csv
#   inflating: train/ex_20.csv
#   inflating: train/ex_23.csv
#   inflating: train/ex_9.csv

# %%
# !ls
# Out:
# can-mirgu.zip					    sample_data  test.zip  train.zip
# micro+gas+turbine+electrical+energy+prediction.zip  test	 train

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ### Turning the csv files into pandas DataFrame
# There are multiple csv files that are joined into one dataframe here.

# %%
train_csv_files = glob.glob('train/*.csv')
train_data = pd.concat([pd.read_csv(file) for file in train_csv_files], ignore_index=True)
#train_data.info()
train_data.head()
# Out:
#      time  input_voltage     el_power
# 0  818.84          3.445  1253.790314
# 1  819.84          3.445  1349.836854
# 2  820.84          3.445  1262.033813
# 3  821.84          3.445  1370.205819
# 4  822.84          3.445  1254.782490

# %% [markdown]
# ### Check the Shape

# %%
train_data.shape
# Out:
# (52940, 3)

# %% [markdown]
# ### Check for Duplicates

# %%
print(train_data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Describe the data

# %%
train_data.describe()
# Out:
#                time  input_voltage      el_power
# count  52940.000000   52940.000000  52940.000000
# mean    5606.444209       5.505534   1843.315949
# std     2960.330233       2.549721    723.126377
# min      810.000000       3.000000    932.837260
# 25%     3086.930000       3.000000   1205.743900
# 50%     5431.033890       4.842105   1605.753998
# 75%     7782.301370       7.421053   2399.419112
# max    12636.840000      10.000000   3249.891217

# %% [markdown]
# ### No Missing Values

# %%
#train_data.isnull().sum()
print(train_data.isnull().mean() * 100)
# Out:
# time             0.0
# input_voltage    0.0
# el_power         0.0
# dtype: float64

# %%
train_data.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52935    False
# 52936    False
# 52937    False
# 52938    False
# 52939    False
# Length: 52940, dtype: bool

# %%
# Time vs input_voltage plot
plt.figure(figsize=(10, 6))
plt.plot(data['time'], data['input_voltage'], label='Input Voltage', color='blue')
plt.xlabel('Time')
plt.ylabel('Input Voltage')
plt.title('Time vs Input Voltage')
plt.legend()
plt.grid(True)
plt.show()

# Time vs el_power plot
plt.figure(figsize=(10, 6))
plt.plot(data['time'], data['el_power'], label='Electrical Power', color='green')
plt.xlabel('Time')
plt.ylabel('Electrical Power')
plt.title('Time vs Electrical Power')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Scatter plot of input_voltage vs el_power
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['input_voltage'], y=data['el_power'], color='purple')
plt.xlabel('Input Voltage')
plt.ylabel('Electrical Power')
plt.title('Input Voltage vs Electrical Power')
plt.grid(True)
plt.show()

# %%
train_data.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['input_voltage'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Input Voltage')
plt.ylabel('Frequency')
plt.title('Distribution of Input Voltage')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(data['el_power'], bins=30, color='lightgreen', edgecolor='black')
plt.xlabel('Electrical Power')
plt.ylabel('Frequency')
plt.title('Distribution of Electrical Power')
plt.grid(True)
plt.show()

# %% [markdown]
# # Test Data

# %%
test_csv_files = glob.glob('test/*.csv')
test_data = pd.concat([pd.read_csv(file) for file in test_csv_files], ignore_index=True)
test_data.info()
test_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18285 entries, 0 to 18284
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           18285 non-null  float64
#  1   input_voltage  18285 non-null  float64
#  2   el_power       18285 non-null  float64
# dtypes: float64(3)
# memory usage: 428.7 KB
#     time  input_voltage     el_power
# 0  880.3            3.0  1193.140713
# 1  881.3            3.0  1107.066421
# 2  882.3            3.0  1180.406767
# 3  883.3            3.0  1095.551498
# 4  884.3            3.0  1177.073719

# %%
test_data.describe()
# Out:
#                time  input_voltage      el_power
# count  18285.000000   18285.000000  18285.000000
# mean    5625.268507       5.835780   1956.281925
# std     2814.624259       2.839874    808.696771
# min      758.425813       3.000000   1022.500305
# 25%     3153.738707       3.000000   1215.566656
# 50%     5625.900000       5.000000   1626.421286
# 75%     8067.277924       8.734064   2729.477347
# max    10545.532399      10.000000   3393.228566

# %%
test_data.shape
# Out:
# (18285, 3)

# %%
print(test_data.duplicated().sum())
# Out:
# 0

# %%
# Check the first few rows of each dataset
print("Train data head:")
print(train_data.head())

print("\nTest data head:")
print(test_data.head())

# Check for missing values
print("\nTrain data missing values:")
print(train_data.isnull().sum())

print("\nTest data missing values:")
print(test_data.isnull().sum())

# Check the column data types
print("\nTrain data info:")
print(train_data.info())

print("\nTest data info:")
print(test_data.info())
# Out:
# Train data head:
#      time  input_voltage     el_power
# 0  818.84          3.445  1253.790314
# 1  819.84          3.445  1349.836854
# 2  820.84          3.445  1262.033813
# 3  821.84          3.445  1370.205819
# 4  822.84          3.445  1254.782490
#
# Test data head:
#     time  input_voltage     el_power
# 0  880.3            3.0  1193.140713
# 1  881.3            3.0  1107.066421
# 2  882.3            3.0  1180.406767
# 3  883.3            3.0  1095.551498
# 4  884.3            3.0  1177.073719
#
# Train data missing values:
# time             0
# input_voltage    0
# el_power         0
# dtype: int64
#
# Test data missing values:
# time             0
# input_voltage    0
# el_power         0
# dtype: int64
#
# Train data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52940 entries, 0 to 52939
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           52940 non-null  float64
# ...
